# %% [markdown]
# # Play With Seaborn

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Data set to be used
titanic = sns.load_dataset('titanic')
fmri=sns.load_dataset('fmri')
tips=sns.load_dataset('tips')
flights=sns.load_dataset('flights')
iris=sns.load_dataset('iris')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.count()
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64

# %%
#Let try to make relationship between these numeric features
sns.scatterplot(x='age',y='fare',data=titanic)
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.scatterplot(x='age',y='fare',hue='sex',data=titanic)#hue is used to differentiate between the data
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.scatterplot(x='age',y='fare',hue='alive',data=titanic)#hue is used to differentiate between the data
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.scatterplot(x='age',y='fare',data=titanic,hue='sex',style='sex')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
plt.figure(figsize=(24,20))
sns.scatterplot(data=titanic,x='age',y='fare',hue='sex',style='pclass')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
plt.figure(figsize=(12,10))
markers=['o','v','s']
sns.scatterplot(data=titanic,x='age',y='fare',hue='sex',style='pclass',markers=markers ,s=100)
# sns.scatterplot(data=titanic, x='age', y='fare', hue='sex', size='sex', sizes=(20,200))
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
#Lets Try to make a line plot
sns.lineplot(x='timepoint',y='signal',data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.regplot(x='timepoint',y='signal',data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.relplot(data=flights, x='month', y='passengers', kind='line')

# %%
sns.relplot(data=flights, x='year', y='passengers', kind='line')

# %%
sns.set_theme(style='darkgrid')
sns.relplot(data=flights, x='year', y='passengers', kind='line')

# %%
sns.relplot(data=flights, x='year', y='passengers', kind='line',hue='month')

# %%
sns.relplot(data=flights, x='month', y='passengers', ci=None, estimator=None, kind='line')
# Out:
# C:\Users\amazon\AppData\Roaming\Python\Python311\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
sns.relplot(data=fmri, x='timepoint', y='signal', 
            hue='event', kind='line',style='event',markers=True)

# %%
sns.relplot(data=fmri, x='timepoint', y='signal', hue='event',kind='line',style='event',dashes=False,markers=True)

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',col='time',data=tips)

# %%
fmri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1064 entries, 0 to 1063
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   subject    1064 non-null   object
#  1   timepoint  1064 non-null   int64
#  2   event      1064 non-null   object
#  3   region     1064 non-null   object
#  4   signal     1064 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 41.7+ KB

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x='timepoint',y='signal',hue='subject',col='region',row='event',height=4,kind='line',estimator=None,data=fmri)

# %% [markdown]
# ## Distribution Plots

# %% [markdown]
# 1. displot()
# 2. jointplot()
# 3. pairpoint()
# 4. rugplot()
# 5. kdeplot()

# %%
sns.displot(titanic['age'])

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.displot(titanic['sex'],kde=False,bins=10)#Kernel Destiny Estimator

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(tips,x='day',shrink=.8)
# Out:
# <Axes: xlabel='day', ylabel='Count'>

# %%
sns.displot(titanic,x='age',hue='pclass')

# %%
sns.displot(titanic,x='sex',hue='age')

# %%
sns.histplot(titanic,x='age',hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(titanic,x='age',hue='survived')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(titanic,x='age',hue='sex',multiple='stack')#Make stacked marked using multiple
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# ### Plotting Bivariate Data with Jointplot()
#
# We use jointplot() to plot two variables with bivariate and univariate graphs. We can have the following options in `kind`: `scatter, reg, resid, kde, hex`. The default `kind` is `scatter`.

# %%
sns.jointplot(tips,x='total_bill',y='tip')

# %%
sns.jointplot(tips,x='total_bill',y='tip',kind='hex')

# %%
sns.jointplot(tips,x='total_bill',y='tip',kind='reg')

# %%
sns.jointplot(tips,x='total_bill',y='tip',kind='resid')

# %%
sns.jointplot(tips,x='total_bill',y='tip',kind='kde',hue='day')

# %% [markdown]
# ### Plotting Many Distribution with pairplot()
#
# pairplot() visualize all possible distributions of variables in datasets. This is a cool plot, you can immmediately see relationships between features.

# %%
sns.pairplot(titanic)

# %%
sns.pairplot(tips)

# %% [markdown]
# ### Plotting Distributions with rugplot()
#
# rugplot() plot marginal distributions by drawing ticks or dash along the x and y axis of the univariate variable.

# %%
sns.rugplot(tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(tips,x='total_bill',y='tip')

# %%
sns.relplot(tips,x='total_bill',y='tip')
sns.rugplot(data=tips, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.kdeplot(tips)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.displot(titanic,x='age',kind='kde',hue='survived')

# %%
sns.kdeplot(tips,x='tip',hue='day',multiple='stack')
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.displot(data=tips, x='tip', hue='day', kind='kde', fill=True)

# %%
sns.displot(titanic,x='age',kind='ecdf')

# %% [markdown]
# ## Categorical Plots
#
# Categorical plots are used to visualize the categorical data.
#
# In Seaborn, there are various plot functions that we are going to see:
#
# 1. Categorical estimate plots
#
# * barplot()
# * countplot()
# * pointplot()
#
# 2. Categorical distribution plots
#
# * boxplot()
# * boxenplot()
# * violinplot()
#
# 3. Categorical scatter plots
# * stripplot()
# * swarmplot()

# %%
sns.catplot(data=titanic,x='sex',y='survived',hue='pclass',kind='bar')

# %%
sns.barplot(data=tips, x='sex', y='total_bill', palette='rocket', hue='day')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.pointplot(titanic,x='sex',y='survived',hue='pclass',palette='dark')
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.boxplot(tips,x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(data=tips, x='day', y='total_bill', hue='smoker', kind='box')

# %%
sns.catplot(data=tips, x='day', y='total_bill', hue='smoker', kind='boxen')

# %%
sns.violinplot(data=tips, x='day', y='total_bill', palette='autumn')
# Out:
# C:\Users\amazon\AppData\Local\Temp\ipykernel_15352\2063146644.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=tips, x='day', y='total_bill', palette='autumn')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(data=tips, x='total_bill', y='day', 
            hue='sex', kind='violin', split=True)

# %%
sns.stripplot(data=tips, x='day', y='total_bill', jitter=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(data=tips, x='day', y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(data=tips, x='total_bill', y='day', hue='sex', kind='swarm')

# %%
sns.catplot(data=tips, x='day', y='total_bill', hue='smoker',
            col='time', kind='swarm')
